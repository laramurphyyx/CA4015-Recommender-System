# %%
import pandas as pd
import numpy as np
import heapq

# %%
artists = pd.read_table('../data/artists.dat', sep="\t")
user_taggedartists = pd.read_table('../data/user_taggedartists.dat', sep="\t")
tags = pd.read_table('../data/tags.dat', sep="\t", encoding='latin-1')
user_artists_ratings = pd.read_csv('../data/user_artists_ratings.csv')
user_artists_ratings.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ## Finding the top 2 tags per artist

# %%
artists['first_tag'] = 0
artists['second_tag'] = 0

# %%
for artist in user_taggedartists.artistID.unique():
    artist_data = user_taggedartists[user_taggedartists['artistID']==artist]
    if len(artist_data) < 1:
        first_tag = 0
        second_tag = 0
    else:
        top_two_tags = artist_data['tagID'].value_counts()[:3].index.tolist()
        first_tag = top_two_tags[0]
        if len(top_two_tags)>1:
            second_tag = top_two_tags[1]
        else:
            second_tag = 0
    artists.loc[artists.id == artist, 'first_tag'] = first_tag
    artists.loc[artists.id == artist, 'second_tag'] = second_tag

# %%
artists
# Out:
#           id               name                                           url  \
# 0          1       MALICE MIZER         http://www.last.fm/music/MALICE+MIZER
# 1          2    Diary of Dreams      http://www.last.fm/music/Diary+of+Dreams
# 2          3  Carpathian Forest    http://www.last.fm/music/Carpathian+Forest
# 3          4       Moi dix Mois         http://www.last.fm/music/Moi+dix+Mois
# 4          5        Bella Morte          http://www.last.fm/music/Bella+Morte
# ...      ...                ...                                           ...
# 17627  18741     Diamanda Galás  http://www.last.fm/music/Diamanda+Gal%C3%A1s
# 17628  18742             Aya RL               http://www.last.fm/music/Aya+RL
# 17629  18743        Coptic Rain          http://www.last.fm/music/Coptic+Rain
# 17630  18744       Oz Alchemist         http://www.last.fm/music/Oz+Alchemist
# 17631  18745   Grzegorz Tomczak     http://www.last.fm/music/Grzegorz+Tomczak
#
#                                               pictureURL  first_tag  \
# 0        http://userserve-ak.last.fm/serve/252/10808.jpg        139
# 1      http://userserve-ak.last.fm/serve/252/3052066.jpg        575
# 2      http://userserve-ak.last.fm/serve/252/40222717...          4
# 3      http://userserve-ak.last.fm/serve/252/54697835...        139
# 4      http://userserve-ak.last.fm/serve/252/14789013...        575
# ...                                                  ...        ...
# 17627  http://userserve-ak.last.fm/serve/252/16352971...         33
# 17628   http://userserve-ak.last.fm/serve/252/207445.jpg          0
# 17629   http://userserve-ak.last.fm/serve/252/344868.jpg          0
# 17630  http://userserve-ak.last.fm/serve/252/29297695...         13
# 17631  http://userserve-ak.last.fm/serve/252/59486303...          0
#
#        second_tag
# 0             141
# 1              30
# 2            3706
# 3             541
# 4             179
# ...           ...
# 17627       11861
# 17628           0
# 17629           0
# 17630          14
# 17631           0
#
# [17632 rows x 6 columns]

# %%
artists.to_csv('../data/artists_tags.csv', index=False)
